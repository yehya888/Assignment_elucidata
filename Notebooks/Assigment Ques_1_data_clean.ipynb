# %%
import cmapPy

# %%
import pandas as pd
import numpy as np

# %%
pd
# Out:
# <module 'pandas' from 'C:\Users\Mohamed\Anaconda3\envs\my_cmapPy_env\lib\site-packages\pandas\__init__.pyc'>

# %%
 import cmapPy.pandasGEXpress.parse as pa

# %%
df=pa.parse("PAAD.gct", convert_neg_666=True)

# %%
df

# %%
df1=df.data_df
df1.head()
# Out:
# cid      aab1-Primary solid Tumor  aab4-Primary solid Tumor  \
# rid
# SLC35E2                      7.45                       8.1
# A1BG                         6.40                       5.8
# A1CF                         4.70                       5.7
# A2BP1                       -1.00                       1.1
# A2LD1                        7.50                       6.8
#
# cid      aab6-Primary solid Tumor  aab8-Primary solid Tumor  \
# rid
# SLC35E2                       7.2                       8.0
# A1BG                          6.4                       5.8
# A1CF                          3.0                       5.1
# A2BP1                         NaN                       NaN
# A2LD1                         7.3                       7.5
#
# cid      aab9-Primary solid Tumor  aaba-Primary solid Tumor  \
# rid
# SLC35E2                      7.65                       8.1
# A1BG                         6.70                       6.6
# ...

# %%
missing_data = df1.isnull()

# %%
missing_data.head()
# Out:
# cid      aab1-Primary solid Tumor  aab4-Primary solid Tumor  \
# rid
# SLC35E2                     False                     False
# A1BG                        False                     False
# A1CF                        False                     False
# A2BP1                       False                     False
# A2LD1                       False                     False
#
# cid      aab6-Primary solid Tumor  aab8-Primary solid Tumor  \
# rid
# SLC35E2                     False                     False
# A1BG                        False                     False
# A1CF                        False                     False
# A2BP1                        True                      True
# A2LD1                       False                     False
#
# cid      aab9-Primary solid Tumor  aaba-Primary solid Tumor  \
# rid
# SLC35E2                     False                     False
# A1BG                        False                     False
# ...

# %%
for row in missing_data.index.tolist():
    print(row)
    print(missing_data.loc[row].value_counts())
    print("")
# Out:
# SLC35E2
# False    183
# Name: SLC35E2, dtype: int64
#
# A1BG
# False    183
# Name: A1BG, dtype: int64
#
# A1CF
# False    181
# True       2
# Name: A1CF, dtype: int64
#
# A2BP1
# False    141
# True      42
# Name: A2BP1, dtype: int64
#
# A2LD1
# False    183
# Name: A2LD1, dtype: int64
#
# A2ML1
# False    156
# True      27
# Name: A2ML1, dtype: int64
#
# A2M
# False    183
# Name: A2M, dtype: int64
#
# A4GALT
# False    183
# Name: A4GALT, dtype: int64
#
# A4GNT
# False    174
# True       9
# Name: A4GNT, dtype: int64
#
# AAA1
# False    125
# True      58
# Name: AAA1, dtype: int64
#
# AAAS
# False    183
# Name: AAAS, dtype: int64
#
# AACSL
# False    107
# True      76
# Name: AACSL, dtype: int64
#
# AACS
# False    183
# Name: AACS, dtype: int64
#
# AADAC
# False    179
# True       4
# Name: AADAC, dtype: int64
#
# AADAT
# False    183
# Name: AADAT, dtype: int64
#
# AAGAB
# False    183
# Name: AAGAB, dtype: int64
#
# AAK1
# False    183
# Name: AAK1, dtype: int64
#
# ...

# %%
df1.isnull().sum(axis=1)
# Out:
# rid
# SLC35E2       0
# A1BG          0
# A1CF          2
# A2BP1        42
# A2LD1         0
# A2ML1        27
# A2M           0
# A4GALT        0
# A4GNT         9
# AAA1         58
# AAAS          0
# AACSL        76
# AACS          0
# AADAC         4
# AADAT         0
# AAGAB         0
# AAK1          0
# AAMP          0
# AANAT        60
# AARS2         0
# AARSD1        0
# AARS          0
# AASDHPPT      0
# AASDH         0
# AASS          0
# AATF          0
# AATK          0
# ABAT          0
# ABCA10        0
# ABCA11P       0
#              ..
# ZSCAN18       0
# ZSCAN1       11
# ZSCAN20       0
# ZSCAN21       0
# ZSCAN22       0
# ZSCAN23       4
# ZSCAN29       0
# ZSCAN2        0
# ZSCAN4       12
# ZSCAN5A       0
# ZSCAN5B      17
# ZSWIM1        0
# ZSWIM3        0
# ZSWIM4        0
# ZSWIM5        0
# ZSWIM6        0
# ZSWIM7        0
# ZUFSP         0
# ZW10          0
# ZWILCH        0
# ZWINT         0
# ZXDA          0
# ZXDB          0
# ZXDC          0
# ...

# %%
li=df1.isnull().sum(axis=1).tolist()
cnt=0
for i in li:
 if(i!=0):
  cnt+=1 
cnt
# Out:
# 4367

# %% [markdown]
# So Number of genes with NaN Values is :4367

# %%
df.data_df.dropna(axis=0,inplace=True)

# %%
df.data_df.reset_index(drop=True, inplace=True)

# %%
import cmapPy.pandasGEXpress.write_gct as wr
wr.write(df, "PAAD_Clean.gct", data_null='NaN', metadata_null='-666', filler_null='-666', data_float_format='%.4f')

# %%
df.data_df.shape
# Out:
# (14098, 183)
